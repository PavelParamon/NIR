# %% [markdown]
# ## Подключение диска и установка keras.tunes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -U keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.27.1)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.15)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %% [markdown]
# # Инициализация

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D, Flatten, Conv1D, GlobalMaxPooling1D, Dropout, LSTM, GRU
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from kerastuner.tuners import BayesianOptimization
from tensorflow import keras
from keras_tuner import Objective
import pandas as pd
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# <ipython-input-3-8e3e93baa2c2>:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import BayesianOptimization

# %%
# Максимальное количество слов
num_words = 10000
# Максимальная длина комментария
max_comment_len = 50
#Число классов
num_classes = 6

# %% [markdown]
# # Загрузка тренировочных данных

# %%
train = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTrain.csv')

# %%
#Получение комментариев
comments = train['comment_text']

# %%
y_train = train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']]

# %% [markdown]
# # Токенизация

# %%
tokenizer = Tokenizer(num_words=num_words)

# %%
#Обучение токенайзера
tokenizer.fit_on_texts(comments)

# %%
train_sequences = tokenizer.texts_to_sequences(comments)

# %%
x_train = pad_sequences(train_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Оптимизация гиперпараметров

# %%
def build_model(hp):
    activation_choice = hp.Choice('activation', values=['sigmoid', 'tanh', 'relu', 'elu', 'selu'])
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'])
    layers_num = hp.Int('layers_num', 1, 4)
    neurons_num = hp.Int('neurons_num', min_value=128, max_value=1024, step=32)
    embedding_num = hp.Int('embedding_num', min_value=4, max_value=128, step=16)
    embeddings_regularizer = keras.regularizers.l2(
        hp.Choice('embeddings_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))
    kernel_regularizer = keras.regularizers.l2(hp.Choice('kernel_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))

    model = Sequential()
    model.add(Embedding(input_dim=num_words, output_dim=embedding_num, input_length=max_comment_len,
                        embeddings_regularizer=embeddings_regularizer))
    for i in range(layers_num):
        model.add(Dense(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='sigmoid'))

    model.compile(optimizer=optimizer_choice, loss='binary_crossentropy', metrics=[keras.metrics.AUC(name="auc"), "accuracy"])

    return model

# %%
tuner = BayesianOptimization(
    build_model,
    objective=Objective('val_auc', 'max'),
    max_trials=50,
    directory='fnn_toxic_dir'
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# activation (Choice)
# {'default': 'sigmoid', 'conditions': [], 'values': ['sigmoid', 'tanh', 'relu', 'elu', 'selu'], 'ordered': False}
# optimizer (Choice)
# {'default': 'SGD', 'conditions': [], 'values': ['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'], 'ordered': False}
# layers_num (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 4, 'step': 1, 'sampling': 'linear'}
# neurons_num (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 1024, 'step': 32, 'sampling': 'linear'}
# embedding_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# embeddings_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# kernel_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(x_train, y_train, batch_size=1024, epochs=5, validation_split=0.2)
# Out:
# Trial 50 Complete [00h 02m 23s]
# val_auc: 0.9549458026885986
#
# Best val_auc So Far: 0.9641311764717102
# Total elapsed time: 00h 54m 59s

# %%
tuner.results_summary(num_trials=50)
# Out:
# Results summary
# Results in fnn_toxic_dir/untitled_project
# Showing 50 best trials
# Objective(name="val_auc", direction="max")
#
# Trial 44 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 1024
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9641311764717102
#
# Trial 39 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 1024
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9632666707038879
#
# Trial 30 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 1024
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9619022011756897
#
# Trial 46 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 736
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9618916511535645
#
# Trial 08 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 4
# neurons_num: 448
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9612378478050232
#
# Trial 42 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 864
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9603418707847595
#
# Trial 21 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 4
# neurons_num: 480
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9602254629135132
#
# Trial 45 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 832
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9583117961883545
#
# Trial 14 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 3
# neurons_num: 640
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9575130939483643
#
# Trial 41 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 1024
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9572477340698242
#
# Trial 29 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 960
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9564304947853088
#
# Trial 33 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 864
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9563787579536438
#
# Trial 22 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 928
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9562528133392334
#
# Trial 43 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 832
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9560079574584961
#
# Trial 12 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 1024
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9557590484619141
#
# Trial 38 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 864
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9550513029098511
#
# Trial 49 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 1024
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9549458026885986
#
# Trial 47 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 1024
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9537457227706909
#
# Trial 23 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 960
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9529405236244202
#
# Trial 06 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 832
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9529275894165039
#
# Trial 34 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 832
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9525151252746582
#
# Trial 36 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 1024
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9524152278900146
#
# Trial 27 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 864
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9501410126686096
#
# Trial 32 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 1024
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9452412128448486
#
# Trial 48 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 832
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9437834024429321
#
# Trial 26 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 960
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9332104921340942
#
# Trial 04 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 576
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7917835116386414
#
# Trial 35 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 4
# neurons_num: 416
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.7767624855041504
#
# Trial 31 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 1024
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.7573451995849609
#
# Trial 16 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_num: 2
# neurons_num: 160
# embedding_num: 68
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7483530044555664
#
# Trial 17 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_num: 1
# neurons_num: 352
# embedding_num: 68
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7483530044555664
#
# Trial 25 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 992
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7483530044555664
#
# Trial 28 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 928
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.7483530044555664
#
# Trial 01 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_num: 2
# neurons_num: 992
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.7482801079750061
#
# Trial 18 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_num: 3
# neurons_num: 416
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7481697797775269
#
# Trial 24 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_num: 4
# neurons_num: 480
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.719829261302948
#
# Trial 00 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_num: 3
# neurons_num: 512
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.716159999370575
#
# Trial 37 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_num: 2
# neurons_num: 928
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.7123801708221436
#
# Trial 05 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_num: 2
# neurons_num: 832
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7111456394195557
#
# Trial 07 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_num: 2
# neurons_num: 576
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7073814868927002
#
# Trial 20 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_num: 3
# neurons_num: 672
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.6872177124023438
#
# Trial 15 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_num: 4
# neurons_num: 352
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.6120898723602295
#
# Trial 11 summary
# Hyperparameters:
# activation: selu
# optimizer: adadelta
# layers_num: 3
# neurons_num: 992
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.5552714467048645
#
# Trial 09 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_num: 3
# neurons_num: 736
# embedding_num: 4
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.553514838218689
#
# Trial 13 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_num: 4
# neurons_num: 192
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.5325823426246643
#
# Trial 40 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_num: 1
# neurons_num: 1024
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.5115429759025574
#
# Trial 10 summary
# Hyperparameters:
# activation: relu
# optimizer: adadelta
# layers_num: 2
# neurons_num: 256
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.4910813570022583
#
# Trial 02 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_num: 3
# neurons_num: 704
# embedding_num: 20
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.45433759689331055
#
# Trial 19 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_num: 4
# neurons_num: 384
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.44510751962661743
#
# Trial 03 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_num: 4
# neurons_num: 256
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.4118404984474182

# %% [markdown]
# # Загрузка тестовых данных

# %%
test_comments = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTest.csv')

# %%
test_labels = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTestLabels.csv')

# %%
test_full = pd.merge(test_comments, test_labels, on='id')

# %%
test = test_full[test_full['toxic']!=-1]

# %% [markdown]
# # Токенизация

# %%
test_sequences = tokenizer.texts_to_sequences(test['comment_text'])

# %%
y_test = test[['toxic',	'severe_toxic',	'obscene', 'threat',	'insult',	'identity_hate']]

# %%
x_test = pad_sequences(test_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Проверка лучшей модели

# %%
model = tuner.get_best_models(num_models=1)

# %%
model[0].evaluate(x_test, y_test)
# Out:
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.1364 - auc: 0.9555 - accuracy: 0.9015
# [0.13636407256126404, 0.9555056095123291, 0.901450514793396]

# %% [markdown]
# # Сохранение модели

# %%
model[0].save('drive/MyDrive/toxicCommentsDataSet/toxicCommentFNNModel.h5')
