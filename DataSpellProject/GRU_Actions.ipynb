# %% [markdown]
# # Подключение диска и установка keras.tunes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -U keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.15)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %% [markdown]
# # Инициализация

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D, Flatten, Conv1D, GlobalMaxPooling1D, Dropout, LSTM, GRU
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils
from tensorflow import keras
from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# <ipython-input-3-a7f52d95c376>:10: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization

# %%
# Максимальное количество слов
num_words = 10000
# Максимальная длина экшена
max_action_len = 50
#Число классов
num_classes = 15

# %% [markdown]
# # Загрузка тренировочных данных

# %%
train = pd.read_csv('drive/MyDrive/actionsNPCDataSet/trainActions.csv',header=None,
names=['class', 'text'])

# %%
#Получение экшенов
actions = train['text']

# %%
y_train = utils.to_categorical(train['class'] - 1, num_classes)

# %% [markdown]
# # Токенизация

# %%
tokenizer = Tokenizer(num_words=num_words)

# %%
#Обучение токенайзера
tokenizer.fit_on_texts(actions)

# %%
train_sequences = tokenizer.texts_to_sequences(actions)

# %%
x_train = pad_sequences(train_sequences, maxlen=max_action_len)

# %% [markdown]
# # Оптимизация гиперпараметров

# %%
def build_model(hp):
    activation_choice = hp.Choice('activation', values=['sigmoid', 'tanh', 'relu', 'elu', 'selu'])
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'])
    layers_gru_num = hp.Int('layers_gru_num', 0, 2)
    neurons_num = hp.Int('neurons_num', min_value=4, max_value=50, step=8)
    embedding_num = hp.Int('embedding_num', min_value=4, max_value=128, step=16)
    embeddings_regularizer = keras.regularizers.l2(
        hp.Choice('embeddings_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))
    kernel_regularizer = keras.regularizers.l2(hp.Choice('kernel_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))

    model = Sequential()
    model.add(Embedding(input_dim=num_words, output_dim=embedding_num, input_length=max_action_len,
                        embeddings_regularizer=embeddings_regularizer))
    for i in range(layers_gru_num):
        model.add(GRU(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer,return_sequences=True))
    model.add(GRU(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer=optimizer_choice, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
tuner = BayesianOptimization(
    build_model,
    objective='val_accuracy',
    max_trials=75,
    directory='gru_actions_dir'
)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# activation (Choice)
# {'default': 'sigmoid', 'conditions': [], 'values': ['sigmoid', 'tanh', 'relu', 'elu', 'selu'], 'ordered': False}
# optimizer (Choice)
# {'default': 'SGD', 'conditions': [], 'values': ['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'], 'ordered': False}
# layers_gru_num (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 2, 'step': 1, 'sampling': 'linear'}
# neurons_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 50, 'step': 8, 'sampling': 'linear'}
# embedding_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# embeddings_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# kernel_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(x_train, y_train, batch_size=128, epochs=5, validation_split=0.2)
# Out:
# Trial 75 Complete [00h 01m 29s]
# val_accuracy: 0.7278525829315186
#
# Best val_accuracy So Far: 0.9510985016822815
# Total elapsed time: 00h 54m 22s

# %%
tuner.results_summary(num_trials=74)
# Out:
# Results summary
# Results in gru_actions_dir/untitled_project
# Showing 74 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 67 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 28
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9510985016822815
#
# Trial 66 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 44
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9383416175842285
#
# Trial 69 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 36
# embedding_num: 68
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9376328587532043
#
# Trial 26 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9270021319389343
#
# Trial 55 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9262934327125549
#
# Trial 54 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9213323593139648
#
# Trial 53 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9206236600875854
#
# Trial 57 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9177888035774231
#
# Trial 65 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 44
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9156626462936401
#
# Trial 36 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9121190905570984
#
# Trial 73 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 28
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9114103317260742
#
# Trial 13 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9107016324996948
#
# Trial 70 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9107016324996948
#
# Trial 33 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9057406187057495
#
# Trial 42 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9057406187057495
#
# Trial 59 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9029057621955872
#
# Trial 60 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8986534476280212
#
# Trial 47 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.8936924338340759
#
# Trial 29 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8929836750030518
#
# Trial 68 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 36
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.891566276550293
#
# Trial 43 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8908575773239136
#
# Trial 49 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8887314200401306
#
# Trial 21 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8851878046989441
#
# Trial 58 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8809354901313782
#
# Trial 40 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8766831755638123
#
# Trial 44 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8759744763374329
#
# Trial 37 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8738483190536499
#
# Trial 22 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8703047633171082
#
# Trial 56 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8646349906921387
#
# Trial 41 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8618001341819763
#
# Trial 09 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.8610914349555969
#
# Trial 46 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8610914349555969
#
# Trial 25 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 28
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.858965277671814
#
# Trial 63 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8554216623306274
#
# Trial 48 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8447909355163574
#
# Trial 34 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8355776071548462
#
# Trial 39 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.8355776071548462
#
# Trial 50 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8313252925872803
#
# Trial 31 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 44
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8299078941345215
#
# Trial 64 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.8249468207359314
#
# Trial 30 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.8036853075027466
#
# Trial 45 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.8022679090499878
#
# Trial 72 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 28
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7973068952560425
#
# Trial 24 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.7859674096107483
#
# Trial 51 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 44
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.7732104659080505
#
# Trial 35 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 28
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.7689582109451294
#
# Trial 11 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.7682494521141052
#
# Trial 71 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.756909966468811
#
# Trial 74 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 20
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.7278525829315186
#
# Trial 61 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.713678240776062
#
# Trial 28 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.683203399181366
#
# Trial 02 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_gru_num: 2
# neurons_num: 28
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.6789510846138
#
# Trial 20 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 28
# embedding_num: 68
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.5230333209037781
#
# Trial 14 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adam
# layers_gru_num: 0
# neurons_num: 20
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.29978737235069275
#
# Trial 27 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.28703048825263977
#
# Trial 01 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_gru_num: 0
# neurons_num: 44
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.198440819978714
#
# Trial 23 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_gru_num: 0
# neurons_num: 36
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.1807228922843933
#
# Trial 00 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_gru_num: 0
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.16796597838401794
#
# Trial 08 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_gru_num: 2
# neurons_num: 4
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.15733522176742554
#
# Trial 03 summary
# Hyperparameters:
# activation: tanh
# optimizer: SGD
# layers_gru_num: 0
# neurons_num: 28
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.154500350356102
#
# Trial 07 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_gru_num: 0
# neurons_num: 44
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.10701630264520645
#
# Trial 10 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_gru_num: 0
# neurons_num: 4
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.09638553857803345
#
# Trial 16 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.09567682445049286
#
# Trial 05 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_gru_num: 1
# neurons_num: 44
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.07583273947238922
#
# Trial 17 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_gru_num: 0
# neurons_num: 44
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.07441531121730804
#
# Trial 38 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.07441531121730804
#
# Trial 12 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_gru_num: 1
# neurons_num: 20
# embedding_num: 20
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.07087172567844391
#
# Trial 18 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_gru_num: 1
# neurons_num: 28
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.07087172567844391
#
# Trial 15 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_gru_num: 0
# neurons_num: 28
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.07016300410032272
#
# Trial 19 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_gru_num: 1
# neurons_num: 4
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.07016300410032272
#
# Trial 62 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_gru_num: 2
# neurons_num: 12
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.07016300410032272
#
# Trial 52 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_gru_num: 1
# neurons_num: 44
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.065910704433918
#
# Trial 04 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_gru_num: 0
# neurons_num: 4
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.06378454715013504
#
# Trial 06 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_gru_num: 2
# neurons_num: 4
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.05669737607240677

# %% [markdown]
# # Загрузка тестовых данных

# %%
test_actions = pd.read_csv('drive/MyDrive/actionsNPCDataSet/actionsTest.csv',header=None,
names=['class', 'text'])

# %%
#Получение экшенов
test_actions = train['text']

# %%
y_test = utils.to_categorical(train['class'] - 1, num_classes)

# %% [markdown]
# # Токенизация

# %%
test_sequences = tokenizer.texts_to_sequences(test_actions)

# %%
x_test = pad_sequences(test_sequences, maxlen=max_action_len)

# %% [markdown]
# # Проверка лучшей модели

# %%
model = tuner.get_best_models(num_models=1)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model[0].evaluate(x_test, y_test)
# Out:
# 221/221 [==============================] - 8s 34ms/step - loss: 0.2145 - accuracy: 0.9834
# [0.2145022451877594, 0.9834066033363342]

# %% [markdown]
# # Сохранение модели

# %%
model[0].save('drive/MyDrive/actionsNPCDataSet/actionsGRUModel.h5')
