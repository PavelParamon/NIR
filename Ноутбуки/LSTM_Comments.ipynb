# %% [markdown]
# ## Подключение диска и установка keras.tunes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -U keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.0.12)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %% [markdown]
# # Инициализация

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D, Flatten, Conv1D, GlobalMaxPooling1D, Dropout, LSTM, GRU, SimpleRNN
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from kerastuner.tuners import BayesianOptimization
from tensorflow import keras
from keras_tuner import Objective
import pandas as pd
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# <ipython-input-3-888032ba30a2>:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import BayesianOptimization

# %%
# Максимальное количество слов
num_words = 10000
# Максимальная длина комментария
max_comment_len = 50
#Число классов
num_classes = 6

# %% [markdown]
# # Загрузка тренировочных данных

# %%
train = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTrain.csv')

# %%
#Получение комментариев
comments = train['comment_text']

# %%
y_train = train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']]

# %% [markdown]
# # Токенизация

# %%
tokenizer = Tokenizer(num_words=num_words)

# %%
#Обучение токенайзера
tokenizer.fit_on_texts(comments)

# %%
train_sequences = tokenizer.texts_to_sequences(comments)

# %%
x_train = pad_sequences(train_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Оптимизация гиперпараметров

# %%
def build_model(hp):
    activation_choice = hp.Choice('activation', values=['sigmoid', 'tanh', 'relu', 'elu', 'selu'])
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'])
    layers_lstm_num = hp.Int('layers_lstm_num', 0, 2)
    neurons_num = hp.Int('neurons_num', min_value=4, max_value=50, step=8)
    embedding_num = hp.Int('embedding_num', min_value=4, max_value=128, step=16)
    embeddings_regularizer = keras.regularizers.l2(
        hp.Choice('embeddings_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))
    kernel_regularizer = keras.regularizers.l2(hp.Choice('kernel_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))

    model = Sequential()
    model.add(Embedding(input_dim=num_words, output_dim=embedding_num, input_length=max_comment_len,
                        embeddings_regularizer=embeddings_regularizer))
    for i in range(layers_lstm_num):
        model.add(LSTM(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer,return_sequences=True))
    model.add(LSTM(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer))
    model.add(Dense(num_classes, activation='sigmoid'))

    model.compile(optimizer=optimizer_choice, loss='binary_crossentropy', metrics=[keras.metrics.AUC(name="auc"), "accuracy"])

    return model

# %%
tuner = BayesianOptimization(
    build_model,
    objective=Objective('val_auc', 'max'),
    max_trials=50,
    directory='lstm_toxic_dir'
)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# activation (Choice)
# {'default': 'sigmoid', 'conditions': [], 'values': ['sigmoid', 'tanh', 'relu', 'elu', 'selu'], 'ordered': False}
# optimizer (Choice)
# {'default': 'SGD', 'conditions': [], 'values': ['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'], 'ordered': False}
# layers_lstm_num (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 2, 'step': 1, 'sampling': 'linear'}
# neurons_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 50, 'step': 8, 'sampling': 'linear'}
# embedding_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# embeddings_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# kernel_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(x_train, y_train, batch_size=1024, epochs=5, validation_split=0.2)
# Out:
# Trial 50 Complete [00h 01m 24s]
# val_auc: 0.6639765501022339
#
# Best val_auc So Far: 0.9702034592628479
# Total elapsed time: 02h 01m 05s

# %%
results_summary = tuner.results_summary(num_trials=50)
# Out:
# Results summary
# Results in lstm_toxic_dir/untitled_project
# Showing 50 best trials
# Objective(name="val_auc", direction="max")
#
# Trial 44 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 28
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9702034592628479
#
# Trial 30 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.969102680683136
#
# Trial 47 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9667857885360718
#
# Trial 36 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9654929637908936
#
# Trial 38 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9643517136573792
#
# Trial 40 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9631429314613342
#
# Trial 45 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 20
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9599244594573975
#
# Trial 20 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9597789645195007
#
# Trial 48 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9561944603919983
#
# Trial 09 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 20
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9526665210723877
#
# Trial 31 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 20
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9503547549247742
#
# Trial 33 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9492428302764893
#
# Trial 22 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.948966920375824
#
# Trial 41 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9482594132423401
#
# Trial 42 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 12
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9455406665802002
#
# Trial 35 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9429764151573181
#
# Trial 37 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 4
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9413046836853027
#
# Trial 15 summary
# Hyperparameters:
# activation: selu
# optimizer: adam
# layers_lstm_num: 0
# neurons_num: 4
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9407180547714233
#
# Trial 46 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9353135824203491
#
# Trial 14 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_lstm_num: 0
# neurons_num: 36
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9350419640541077
#
# Trial 32 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9307952523231506
#
# Trial 23 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9142347574234009
#
# Trial 34 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9104067087173462
#
# Trial 24 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.8976640701293945
#
# Trial 16 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 20
# embedding_num: 20
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.8804049491882324
#
# Trial 13 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_lstm_num: 1
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.7989451289176941
#
# Trial 43 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_lstm_num: 0
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.7848750948905945
#
# Trial 27 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_lstm_num: 1
# neurons_num: 4
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.7629345655441284
#
# Trial 25 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.7561915516853333
#
# Trial 07 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_lstm_num: 2
# neurons_num: 4
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.7483530640602112
#
# Trial 39 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 4
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.7482046484947205
#
# Trial 06 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_lstm_num: 2
# neurons_num: 44
# embedding_num: 4
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.7456755638122559
#
# Trial 21 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_lstm_num: 2
# neurons_num: 36
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7122275829315186
#
# Trial 18 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_lstm_num: 2
# neurons_num: 4
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.6641896367073059
#
# Trial 49 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_lstm_num: 0
# neurons_num: 4
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.6639765501022339
#
# Trial 12 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.6608089208602905
#
# Trial 10 summary
# Hyperparameters:
# activation: tanh
# optimizer: SGD
# layers_lstm_num: 0
# neurons_num: 20
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.6462894082069397
#
# Trial 17 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_lstm_num: 0
# neurons_num: 4
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.6429192423820496
#
# Trial 28 summary
# Hyperparameters:
# activation: relu
# optimizer: adadelta
# layers_lstm_num: 1
# neurons_num: 44
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.6172628998756409
#
# Trial 29 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.5821415185928345
#
# Trial 19 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.5406948924064636
#
# Trial 04 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.5075932145118713
#
# Trial 05 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_lstm_num: 0
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.4984112083911896
#
# Trial 00 summary
# Hyperparameters:
# activation: relu
# optimizer: adagrad
# layers_lstm_num: 0
# neurons_num: 44
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.49049219489097595
#
# Trial 26 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adam
# layers_lstm_num: 1
# neurons_num: 4
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.48093587160110474
#
# Trial 11 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_lstm_num: 1
# neurons_num: 36
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.4777114987373352
#
# Trial 08 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_lstm_num: 1
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.4690522253513336
#
# Trial 02 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.45292073488235474
#
# Trial 03 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 68
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.43577340245246887
#
# Trial 01 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_lstm_num: 1
# neurons_num: 36
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.40725091099739075

# %% [markdown]
# # Загрузка тестовых данных

# %%
test_comments = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTest.csv')

# %%
test_labels = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTestLabels.csv')

# %%
test_full = pd.merge(test_comments, test_labels, on='id')

# %%
test = test_full[test_full['toxic']!=-1]

# %% [markdown]
# # Токенизация

# %%
test_sequences = tokenizer.texts_to_sequences(test['comment_text'])

# %%
y_test = test[['toxic',	'severe_toxic',	'obscene', 'threat',	'insult',	'identity_hate']]

# %%
x_test = pad_sequences(test_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Проверка лучшей модели

# %%
model = tuner.get_best_models(num_models=1)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model[0].evaluate(x_test, y_test)
# Out:
# 2000/2000 [==============================] - 52s 26ms/step - loss: 0.0978 - auc: 0.9616 - accuracy: 0.9976
# [0.09775559604167938, 0.9615615606307983, 0.9976085424423218]

# %% [markdown]
# # Сохранение модели

# %%
model[0].save('drive/MyDrive/toxicCommentsDataSet/toxicCommentLSTMModel.h5')
