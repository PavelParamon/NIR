# %% [markdown]
# ## Подключение диска и установка keras.tunes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -U keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (3.4)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %% [markdown]
# # Инициализация

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D, Flatten, Conv1D, GlobalMaxPooling1D, Dropout, LSTM, GRU
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils
from tensorflow import keras
from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# <ipython-input-3-a7f52d95c376>:10: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization

# %%
# Максимальное количество слов
num_words = 10000
# Максимальная длина комментария
max_comment_len = 50
#Число классов
num_classes = 6

# %% [markdown]
# # Загрузка тренировочных данных

# %%
train = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTrain.csv')

# %%
#Получение комментариев
comments = train['comment_text']

# %%
y_train = train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']]

# %% [markdown]
# # Токенизация

# %%
tokenizer = Tokenizer(num_words=num_words)

# %%
#Обучение токенайзера
tokenizer.fit_on_texts(comments)

# %%
train_sequences = tokenizer.texts_to_sequences(comments)

# %%
x_train = pad_sequences(train_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Оптимизация гиперпараметров

# %%
def build_model(hp):
    activation_choice = hp.Choice('activation', values=['sigmoid', 'tanh', 'relu', 'elu', 'selu'])
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'])
    layers_lstm_num = hp.Int('layers_lstm_num', 0, 2)
    neurons_num = hp.Int('neurons_num', min_value=4, max_value=50, step=8)
    embedding_num = hp.Int('embedding_num', min_value=4, max_value=128, step=16)
    embeddings_regularizer = keras.regularizers.l2(
        hp.Choice('embeddings_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))
    kernel_regularizer = keras.regularizers.l2(hp.Choice('kernel_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))

    model = Sequential()
    model.add(Embedding(input_dim=num_words, output_dim=embedding_num, input_length=max_comment_len,
                        embeddings_regularizer=embeddings_regularizer))
    for i in range(layers_lstm_num):
        model.add(LSTM(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer,return_sequences=True))
    model.add(LSTM(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer))
    model.add(Dense(num_classes, activation='sigmoid'))

    model.compile(optimizer=optimizer_choice, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
tuner = BayesianOptimization(
    build_model,
    objective='val_accuracy',
    max_trials=50,
    directory='lstm_toxic_dir'
)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# activation (Choice)
# {'default': 'sigmoid', 'conditions': [], 'values': ['sigmoid', 'tanh', 'relu', 'elu', 'selu'], 'ordered': False}
# optimizer (Choice)
# {'default': 'SGD', 'conditions': [], 'values': ['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'], 'ordered': False}
# layers_lstm_num (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 2, 'step': 1, 'sampling': 'linear'}
# neurons_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 50, 'step': 8, 'sampling': 'linear'}
# embedding_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# embeddings_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# kernel_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(x_train, y_train, batch_size=1024, epochs=5, validation_split=0.2)
# Out:
# Trial 50 Complete [00h 03m 09s]
# val_accuracy: 0.9941093325614929
#
# Best val_accuracy So Far: 0.9941093325614929
# Total elapsed time: 01h 43m 03s

# %%
results_summary = tuner.results_summary(num_trials=50)
# Out:
# Results summary
# Results in lstm_toxic_dir/untitled_project
# Showing 50 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 01 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 04 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 08 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_lstm_num: 0
# neurons_num: 44
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 09 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_lstm_num: 2
# neurons_num: 28
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.9941093325614929
#
# Trial 14 summary
# Hyperparameters:
# activation: relu
# optimizer: adagrad
# layers_lstm_num: 1
# neurons_num: 44
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9941093325614929
#
# Trial 18 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_lstm_num: 1
# neurons_num: 4
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 19 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_lstm_num: 2
# neurons_num: 36
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 24 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 4
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9941093325614929
#
# Trial 27 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9941093325614929
#
# Trial 28 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9941093325614929
#
# Trial 32 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9941093325614929
#
# Trial 36 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9941093325614929
#
# Trial 37 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9941093325614929
#
# Trial 39 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9941093325614929
#
# Trial 41 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 12
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9941093325614929
#
# Trial 43 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 45 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 47 summary
# Hyperparameters:
# activation: selu
# optimizer: adam
# layers_lstm_num: 2
# neurons_num: 28
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 48 summary
# Hyperparameters:
# activation: selu
# optimizer: adam
# layers_lstm_num: 1
# neurons_num: 20
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 49 summary
# Hyperparameters:
# activation: selu
# optimizer: adam
# layers_lstm_num: 2
# neurons_num: 28
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9941093325614929
#
# Trial 05 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_lstm_num: 0
# neurons_num: 36
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9939213395118713
#
# Trial 25 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 68
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9938586950302124
#
# Trial 38 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.99276202917099
#
# Trial 40 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 20
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.992292046546936
#
# Trial 06 summary
# Hyperparameters:
# activation: relu
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9920413494110107
#
# Trial 33 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9918533563613892
#
# Trial 34 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9902867078781128
#
# Trial 35 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.9888767004013062
#
# Trial 11 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9888140559196472
#
# Trial 42 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 1
# neurons_num: 12
# embedding_num: 116
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.9879053831100464
#
# Trial 23 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9848660230636597
#
# Trial 12 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 0
# neurons_num: 4
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9682907462120056
#
# Trial 30 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9416261911392212
#
# Trial 21 summary
# Hyperparameters:
# activation: relu
# optimizer: adagrad
# layers_lstm_num: 0
# neurons_num: 36
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7963653206825256
#
# Trial 07 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 4
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7466394901275635
#
# Trial 22 summary
# Hyperparameters:
# activation: relu
# optimizer: adagrad
# layers_lstm_num: 2
# neurons_num: 28
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.6314272284507751
#
# Trial 26 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 12
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.45379915833473206
#
# Trial 00 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_lstm_num: 1
# neurons_num: 4
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.3941720128059387
#
# Trial 46 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 36
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.3932633697986603
#
# Trial 10 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_lstm_num: 0
# neurons_num: 12
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.26451513171195984
#
# Trial 15 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_lstm_num: 0
# neurons_num: 44
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.010903963819146156
#
# Trial 44 summary
# Hyperparameters:
# activation: tanh
# optimizer: SGD
# layers_lstm_num: 2
# neurons_num: 28
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.0034466551151126623
#
# Trial 13 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_lstm_num: 0
# neurons_num: 4
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.0020366599783301353
#
# Trial 03 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_lstm_num: 1
# neurons_num: 28
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.0006579977925866842
#
# Trial 17 summary
# Hyperparameters:
# activation: relu
# optimizer: adadelta
# layers_lstm_num: 0
# neurons_num: 4
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.0006579977925866842
#
# Trial 20 summary
# Hyperparameters:
# activation: selu
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 44
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.0005326648824848235
#
# Trial 31 summary
# Hyperparameters:
# activation: relu
# optimizer: adadelta
# layers_lstm_num: 2
# neurons_num: 4
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.00021933260723017156
#
# Trial 02 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_lstm_num: 0
# neurons_num: 20
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.00018799937970470637
#
# Trial 16 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_lstm_num: 1
# neurons_num: 44
# embedding_num: 4
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 6.266645505093038e-05
#
# Trial 29 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_lstm_num: 2
# neurons_num: 20
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.0

# %% [markdown]
# # Загрузка тестовых данных

# %%
test_comments = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTest.csv')

# %%
test_labels = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTestLabels.csv')

# %%
test_full = pd.merge(test_comments, test_labels, on='id')

# %%
test = test_full[test_full['toxic']!=-1]

# %% [markdown]
# # Токенизация

# %%
test_sequences = tokenizer.texts_to_sequences(test['comment_text'])

# %%
y_test = test[['toxic',	'severe_toxic',	'obscene', 'threat',	'insult',	'identity_hate']]

# %%
x_test = pad_sequences(test_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Проверка лучшей модели

# %%
model = tuner.get_best_models(num_models=1)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model[0].evaluate(x_test, y_test)
# Out:
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.6874 - accuracy: 0.9976
# [0.6873722672462463, 0.9976085424423218]

# %% [markdown]
# # Сохранение модели

# %%
model[0].save('drive/MyDrive/toxicCommentsDataSet/toxicCommentLSTMModel.h5')
