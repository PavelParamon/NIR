# %% [markdown]
# # Подключение диска и установка keras.tunes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -U keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 14.5 MB/s eta 0:00:00
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (3.4)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %% [markdown]
# # Инициализация

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D, Flatten
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils
from tensorflow import keras
from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# <ipython-input-3-13bcad876f47>:10: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization

# %%
# Максимальное количество слов
num_words = 10000
# Максимальная длина экшена
max_action_len = 50
#Число классов
num_classes = 15

# %% [markdown]
# # Загрузка тренировочных данных

# %%
train = pd.read_csv('drive/MyDrive/actionsNPCDataSet/trainActions.csv',header=None,
names=['class', 'text'])

# %%
#Получение экшенов
actions = train['text']

# %%
y_train = utils.to_categorical(train['class'] - 1, num_classes)

# %% [markdown]
# # Токенизация

# %%
tokenizer = Tokenizer(num_words=num_words)

# %%
#Обучение токенайзера
tokenizer.fit_on_texts(actions)

# %%
train_sequences = tokenizer.texts_to_sequences(actions)

# %%
x_train = pad_sequences(train_sequences, maxlen=max_action_len)

# %% [markdown]
# # Оптимизация гиперпараметров

# %%
def build_model(hp):
    activation_choice = hp.Choice('activation', values=['sigmoid', 'tanh', 'relu', 'elu', 'selu'])
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'])
    layers_num = hp.Int('layers_num', 1, 4)
    neurons_num = hp.Int('neurons_num', min_value=128, max_value=1024, step=32)
    embedding_num = hp.Int('embedding_num', min_value=4, max_value=128, step=16)
    embeddings_regularizer = keras.regularizers.l2(
        hp.Choice('embeddings_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))
    kernel_regularizer = keras.regularizers.l2(hp.Choice('kernel_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))

    model = Sequential()
    model.add(Embedding(input_dim=num_words, output_dim=embedding_num, input_length=max_action_len,
                        embeddings_regularizer=embeddings_regularizer))
    for i in range(layers_num):
        model.add(Dense(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer=optimizer_choice, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
tuner = BayesianOptimization(
    build_model,
    objective='val_accuracy',
    max_trials=75,
    directory='fnn_actions_dir'
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 7
# activation (Choice)
# {'default': 'sigmoid', 'conditions': [], 'values': ['sigmoid', 'tanh', 'relu', 'elu', 'selu'], 'ordered': False}
# optimizer (Choice)
# {'default': 'SGD', 'conditions': [], 'values': ['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'], 'ordered': False}
# layers_num (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 4, 'step': 1, 'sampling': 'linear'}
# neurons_num (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 1024, 'step': 32, 'sampling': 'linear'}
# embedding_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# embeddings_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# kernel_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(x_train, y_train, batch_size=128, epochs=5, validation_split=0.2)
# Out:
# Trial 75 Complete [00h 00m 04s]
# val_accuracy: 0.967399001121521
#
# Best val_accuracy So Far: 0.9808646440505981
# Total elapsed time: 00h 09m 00s

# %%
tuner.results_summary(num_trials=74)
# Out:
# Results summary
# Results in fnn_actions_dir/untitled_project
# Showing 74 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 26 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9808646440505981
#
# Trial 34 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9808646440505981
#
# Trial 35 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9787384867668152
#
# Trial 28 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 256
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9780297875404358
#
# Trial 12 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9773210287094116
#
# Trial 01 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 1
# neurons_num: 160
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9766123294830322
#
# Trial 29 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9766123294830322
#
# Trial 30 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 256
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9766123294830322
#
# Trial 32 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9766123294830322
#
# Trial 31 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9759036302566528
#
# Trial 33 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9759036302566528
#
# Trial 16 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 256
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9751948714256287
#
# Trial 25 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 288
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9751948714256287
#
# Trial 49 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9751948714256287
#
# Trial 59 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9737774729728699
#
# Trial 39 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9723600149154663
#
# Trial 65 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9723600149154663
#
# Trial 46 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9716513156890869
#
# Trial 57 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9716513156890869
#
# Trial 21 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 256
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9709426164627075
#
# Trial 24 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 224
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9709426164627075
#
# Trial 63 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9709426164627075
#
# Trial 37 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 41 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 45 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 50 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 55 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 56 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 60 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 68 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9702338576316833
#
# Trial 66 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.969525158405304
#
# Trial 42 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9688164591789246
#
# Trial 61 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9688164591789246
#
# Trial 69 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9688164591789246
#
# Trial 71 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9688164591789246
#
# Trial 47 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9681077003479004
#
# Trial 53 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9681077003479004
#
# Trial 73 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9681077003479004
#
# Trial 44 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.967399001121521
#
# Trial 48 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.967399001121521
#
# Trial 64 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.967399001121521
#
# Trial 74 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.967399001121521
#
# Trial 00 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 2
# neurons_num: 672
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 36 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 160
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 40 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 54 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 58 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 67 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 70 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9666903018951416
#
# Trial 38 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9659816026687622
#
# Trial 43 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9659816026687622
#
# Trial 52 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9659816026687622
#
# Trial 62 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9659816026687622
#
# Trial 51 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 192
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9645641446113586
#
# Trial 11 summary
# Hyperparameters:
# activation: tanh
# optimizer: adam
# layers_num: 1
# neurons_num: 768
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.9588943719863892
#
# Trial 19 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 608
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.5223246216773987
#
# Trial 07 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 224
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.3621545135974884
#
# Trial 03 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 4
# neurons_num: 672
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.187101349234581
#
# Trial 13 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 4
# neurons_num: 832
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.15804393589496613
#
# Trial 08 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 4
# neurons_num: 480
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.13323883712291718
#
# Trial 27 summary
# Hyperparameters:
# activation: tanh
# optimizer: SGD
# layers_num: 1
# neurons_num: 288
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.12969525158405304
#
# Trial 10 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_num: 3
# neurons_num: 512
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.1098511666059494
#
# Trial 20 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_num: 4
# neurons_num: 672
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.1098511666059494
#
# Trial 02 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_num: 2
# neurons_num: 576
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.09780297428369522
#
# Trial 14 summary
# Hyperparameters:
# activation: tanh
# optimizer: SGD
# layers_num: 2
# neurons_num: 704
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.09780297428369522
#
# Trial 09 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 2
# neurons_num: 256
# embedding_num: 4
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.09638553857803345
#
# Trial 17 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_num: 1
# neurons_num: 800
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.09425938874483109
#
# Trial 06 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_num: 3
# neurons_num: 288
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.09142452478408813
#
# Trial 22 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_num: 1
# neurons_num: 160
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.08362863212823868
#
# Trial 05 summary
# Hyperparameters:
# activation: selu
# optimizer: adadelta
# layers_num: 2
# neurons_num: 384
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.07795889675617218
#
# Trial 15 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_num: 2
# neurons_num: 288
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.07795889675617218
#
# Trial 72 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adam
# layers_num: 1
# neurons_num: 960
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.077250175178051
#
# Trial 23 summary
# Hyperparameters:
# activation: tanh
# optimizer: adagrad
# layers_num: 1
# neurons_num: 288
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.07512402534484863
#
# Trial 18 summary
# Hyperparameters:
# activation: selu
# optimizer: adadelta
# layers_num: 3
# neurons_num: 544
# embedding_num: 4
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.06803685426712036

# %% [markdown]
# # Загрузка тестовых данных

# %%
test_actions = pd.read_csv('drive/MyDrive/actionsNPCDataSet/actionsTest.csv',header=None,
names=['class', 'text'])

# %%
#Получение экшенов
test_actions = train['text']

# %%
y_test = utils.to_categorical(train['class'] - 1, num_classes)

# %% [markdown]
# # Токенизация

# %%
test_sequences = tokenizer.texts_to_sequences(test_actions)

# %%
x_test = pad_sequences(test_sequences, maxlen=max_action_len)

# %% [markdown]
# # Проверка лучшей модели

# %%
model = tuner.get_best_models(num_models=1)

# %%
model[0].evaluate(x_test, y_test)
# Out:
# 221/221 [==============================] - 1s 3ms/step - loss: 0.0912 - accuracy: 0.9959
# [0.09117404371500015, 0.9958871006965637]

# %% [markdown]
# # Сохранение модели

# %%
model[0].save('drive/MyDrive/actionsNPCDataSet/actionsFNNModel.h5')
