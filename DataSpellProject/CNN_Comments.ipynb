# %% [markdown]
# ## Подключение диска и установка keras.tunes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -U keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (2.27.1)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->keras-tuner) (1.26.15)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %% [markdown]
# # Инициализация

# %%
# %tensorflow_version 2.x
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Dropout, LSTM, Bidirectional, SpatialDropout1D, Flatten, Conv1D, GlobalMaxPooling1D, Dropout, LSTM, GRU, SimpleRNN
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from kerastuner.tuners import BayesianOptimization
from tensorflow import keras
from keras_tuner import Objective
import pandas as pd
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# <ipython-input-3-8e3e93baa2c2>:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import BayesianOptimization

# %%
# Максимальное количество слов
num_words = 10000
# Максимальная длина комментария
max_comment_len = 50
#Число классов
num_classes = 6

# %% [markdown]
# # Загрузка тренировочных данных

# %%
train = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTrain.csv')

# %%
#Получение комментариев
comments = train['comment_text']

# %%
y_train = train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']]

# %% [markdown]
# # Токенизация

# %%
tokenizer = Tokenizer(num_words=num_words)

# %%
#Обучение токенайзера
tokenizer.fit_on_texts(comments)

# %%
train_sequences = tokenizer.texts_to_sequences(comments)

# %%
x_train = pad_sequences(train_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Оптимизация гиперпараметров

# %%
def build_model(hp):
    activation_choice = hp.Choice('activation', values=['sigmoid', 'tanh', 'relu', 'elu', 'selu'])
    optimizer_choice = hp.Choice('optimizer', values=['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'])
    layers_conv_num = hp.Int('layers_num', 1, 3)
    neurons_num = hp.Int('neurons_num', min_value=12, max_value=256, step=32)
    filter_num = hp.Int('filter_num', min_value=32, max_value=512, step=32)
    kernel_size = hp.Int('kernel_size', min_value=1, max_value=5, step=1)
    embedding_num = hp.Int('embedding_num', min_value=4, max_value=128, step=16)
    embeddings_regularizer = keras.regularizers.l2(
        hp.Choice('embeddings_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))
    kernel_regularizer = keras.regularizers.l2(hp.Choice('kernel_regularizer', values=[1e-2, 1e-3, 1e-4], default=1e-3))

    model = Sequential()
    model.add(Embedding(input_dim=num_words, output_dim=embedding_num, input_length=max_comment_len,
                        embeddings_regularizer=embeddings_regularizer))
    for i in range(layers_conv_num):
        model.add(Conv1D(filters=filter_num, kernel_size=kernel_size, activation=activation_choice, kernel_regularizer=kernel_regularizer))
        model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(units=neurons_num, activation=activation_choice, kernel_regularizer=kernel_regularizer))
    model.add(Dense(num_classes, activation='sigmoid'))

    model.compile(optimizer=optimizer_choice, loss='binary_crossentropy', metrics=[keras.metrics.AUC(name="auc"), "accuracy"])

    return model

# %%
tuner = BayesianOptimization(
    build_model,
    objective=Objective('val_auc', 'max'),
    max_trials=50,
    directory='cnn_toxic_dir'
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 9
# activation (Choice)
# {'default': 'sigmoid', 'conditions': [], 'values': ['sigmoid', 'tanh', 'relu', 'elu', 'selu'], 'ordered': False}
# optimizer (Choice)
# {'default': 'SGD', 'conditions': [], 'values': ['SGD', 'adam', 'adagrad', 'adadelta', 'rmsprop'], 'ordered': False}
# layers_num (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': 'linear'}
# neurons_num (Int)
# {'default': None, 'conditions': [], 'min_value': 12, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# filter_num (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# kernel_size (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}
# embedding_num (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# embeddings_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# kernel_regularizer (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.search(x_train, y_train, batch_size=1024, epochs=5, validation_split=0.2)
# Out:
# Trial 50 Complete [00h 00m 42s]
# val_auc: 0.7113415598869324
#
# Best val_auc So Far: 0.9687618613243103
# Total elapsed time: 00h 23m 52s

# %%
results_summary = tuner.results_summary(num_trials=50)
# Out:
# Results summary
# Results in cnn_toxic_dir/untitled_project
# Showing 50 best trials
# Objective(name="val_auc", direction="max")
#
# Trial 45 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 108
# filter_num: 32
# kernel_size: 5
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9687618613243103
#
# Trial 36 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9682829976081848
#
# Trial 31 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9670343995094299
#
# Trial 35 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.9645171165466309
#
# Trial 38 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 108
# filter_num: 32
# kernel_size: 5
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9639298915863037
#
# Trial 39 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 76
# filter_num: 32
# kernel_size: 5
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9632960557937622
#
# Trial 33 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9609679579734802
#
# Trial 43 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 76
# filter_num: 32
# kernel_size: 5
# embedding_num: 84
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9594934582710266
#
# Trial 29 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 12
# filter_num: 32
# kernel_size: 4
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9584397077560425
#
# Trial 15 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 4
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.958001434803009
#
# Trial 46 summary
# Hyperparameters:
# activation: selu
# optimizer: adam
# layers_num: 3
# neurons_num: 108
# filter_num: 512
# kernel_size: 1
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9562309384346008
#
# Trial 30 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 4
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9548482894897461
#
# Trial 34 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.9535458087921143
#
# Trial 44 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 116
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9509721398353577
#
# Trial 24 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 2
# neurons_num: 140
# filter_num: 480
# kernel_size: 2
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9472526907920837
#
# Trial 28 summary
# Hyperparameters:
# activation: elu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 4
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.9464907050132751
#
# Trial 37 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.9446904063224792
#
# Trial 40 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 44
# filter_num: 32
# kernel_size: 5
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.9427742958068848
#
# Trial 10 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 1
# neurons_num: 204
# filter_num: 32
# kernel_size: 5
# embedding_num: 36
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.9331175088882446
#
# Trial 42 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 12
# filter_num: 32
# kernel_size: 5
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.8099191784858704
#
# Trial 04 summary
# Hyperparameters:
# activation: relu
# optimizer: rmsprop
# layers_num: 2
# neurons_num: 44
# filter_num: 160
# kernel_size: 4
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.7916892766952515
#
# Trial 17 summary
# Hyperparameters:
# activation: elu
# optimizer: adam
# layers_num: 1
# neurons_num: 204
# filter_num: 64
# kernel_size: 5
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.01
# Score: 0.7895700931549072
#
# Trial 13 summary
# Hyperparameters:
# activation: tanh
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 76
# filter_num: 32
# kernel_size: 4
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.7767451405525208
#
# Trial 47 summary
# Hyperparameters:
# activation: selu
# optimizer: rmsprop
# layers_num: 3
# neurons_num: 12
# filter_num: 32
# kernel_size: 3
# embedding_num: 116
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.7693899869918823
#
# Trial 03 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_num: 3
# neurons_num: 76
# filter_num: 416
# kernel_size: 4
# embedding_num: 36
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.7541707158088684
#
# Trial 27 summary
# Hyperparameters:
# activation: relu
# optimizer: SGD
# layers_num: 2
# neurons_num: 140
# filter_num: 512
# kernel_size: 2
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7519668340682983
#
# Trial 18 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: SGD
# layers_num: 1
# neurons_num: 140
# filter_num: 448
# kernel_size: 3
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7516569495201111
#
# Trial 20 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: rmsprop
# layers_num: 1
# neurons_num: 140
# filter_num: 480
# kernel_size: 3
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.7483530044555664
#
# Trial 26 summary
# Hyperparameters:
# activation: relu
# optimizer: adam
# layers_num: 2
# neurons_num: 44
# filter_num: 352
# kernel_size: 1
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.7483530044555664
#
# Trial 22 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adagrad
# layers_num: 3
# neurons_num: 108
# filter_num: 512
# kernel_size: 2
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7482789158821106
#
# Trial 25 summary
# Hyperparameters:
# activation: selu
# optimizer: adam
# layers_num: 3
# neurons_num: 204
# filter_num: 480
# kernel_size: 2
# embedding_num: 36
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.7482788562774658
#
# Trial 48 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 2
# neurons_num: 108
# filter_num: 512
# kernel_size: 2
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7471916675567627
#
# Trial 01 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 2
# neurons_num: 12
# filter_num: 384
# kernel_size: 2
# embedding_num: 4
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7400128245353699
#
# Trial 41 summary
# Hyperparameters:
# activation: elu
# optimizer: SGD
# layers_num: 1
# neurons_num: 236
# filter_num: 32
# kernel_size: 5
# embedding_num: 4
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.001
# Score: 0.7314416766166687
#
# Trial 19 summary
# Hyperparameters:
# activation: selu
# optimizer: SGD
# layers_num: 1
# neurons_num: 204
# filter_num: 288
# kernel_size: 1
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.7291297912597656
#
# Trial 12 summary
# Hyperparameters:
# activation: tanh
# optimizer: SGD
# layers_num: 2
# neurons_num: 76
# filter_num: 512
# kernel_size: 2
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.7241531014442444
#
# Trial 49 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_num: 2
# neurons_num: 140
# filter_num: 512
# kernel_size: 1
# embedding_num: 20
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.7113415598869324
#
# Trial 16 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_num: 2
# neurons_num: 140
# filter_num: 416
# kernel_size: 5
# embedding_num: 100
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.6338747143745422
#
# Trial 09 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_num: 2
# neurons_num: 76
# filter_num: 96
# kernel_size: 5
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.6264618039131165
#
# Trial 06 summary
# Hyperparameters:
# activation: elu
# optimizer: adagrad
# layers_num: 2
# neurons_num: 172
# filter_num: 32
# kernel_size: 1
# embedding_num: 20
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.5855979919433594
#
# Trial 00 summary
# Hyperparameters:
# activation: relu
# optimizer: adadelta
# layers_num: 2
# neurons_num: 204
# filter_num: 352
# kernel_size: 2
# embedding_num: 52
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.533573567867279
#
# Trial 14 summary
# Hyperparameters:
# activation: selu
# optimizer: adadelta
# layers_num: 2
# neurons_num: 236
# filter_num: 384
# kernel_size: 1
# embedding_num: 100
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.5298900604248047
#
# Trial 08 summary
# Hyperparameters:
# activation: elu
# optimizer: adadelta
# layers_num: 2
# neurons_num: 172
# filter_num: 352
# kernel_size: 4
# embedding_num: 52
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.001
# Score: 0.49540430307388306
#
# Trial 05 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_num: 1
# neurons_num: 76
# filter_num: 256
# kernel_size: 2
# embedding_num: 100
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.0001
# Score: 0.48609989881515503
#
# Trial 11 summary
# Hyperparameters:
# activation: tanh
# optimizer: adadelta
# layers_num: 3
# neurons_num: 76
# filter_num: 512
# kernel_size: 2
# embedding_num: 84
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.01
# Score: 0.4658246636390686
#
# Trial 02 summary
# Hyperparameters:
# activation: selu
# optimizer: adadelta
# layers_num: 1
# neurons_num: 204
# filter_num: 352
# kernel_size: 1
# embedding_num: 84
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.43483680486679077
#
# Trial 32 summary
# Hyperparameters:
# activation: selu
# optimizer: adagrad
# layers_num: 1
# neurons_num: 12
# filter_num: 32
# kernel_size: 4
# embedding_num: 68
# embeddings_regularizer: 0.0001
# kernel_regularizer: 0.0001
# Score: 0.4160471260547638
#
# Trial 07 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_num: 3
# neurons_num: 44
# filter_num: 480
# kernel_size: 4
# embedding_num: 20
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.01
# Score: 0.39778560400009155
#
# Trial 21 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_num: 3
# neurons_num: 204
# filter_num: 32
# kernel_size: 4
# embedding_num: 52
# embeddings_regularizer: 0.01
# kernel_regularizer: 0.0001
# Score: 0.28881439566612244
#
# Trial 23 summary
# Hyperparameters:
# activation: sigmoid
# optimizer: adadelta
# layers_num: 2
# neurons_num: 76
# filter_num: 288
# kernel_size: 5
# embedding_num: 68
# embeddings_regularizer: 0.001
# kernel_regularizer: 0.001
# Score: 0.28307434916496277

# %% [markdown]
# # Загрузка тестовых данных

# %%
test_comments = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTest.csv')

# %%
test_labels = pd.read_csv('drive/MyDrive/toxicCommentsDataSet/toxicCommentsTestLabels.csv')

# %%
test_full = pd.merge(test_comments, test_labels, on='id')

# %%
test = test_full[test_full['toxic']!=-1]

# %% [markdown]
# # Токенизация

# %%
test_sequences = tokenizer.texts_to_sequences(test['comment_text'])

# %%
y_test = test[['toxic',	'severe_toxic',	'obscene', 'threat',	'insult',	'identity_hate']]

# %%
x_test = pad_sequences(test_sequences, maxlen=max_comment_len)

# %% [markdown]
# # Проверка лучшей модели

# %%
model = tuner.get_best_models(num_models=1)

# %%
model[0].evaluate(x_test, y_test)
# Out:
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1116 - auc: 0.9609 - accuracy: 0.9386
# [0.11155866086483002, 0.9609448909759521, 0.9385726451873779]

# %% [markdown]
# # Сохранение модели

# %%
model[0].save('drive/MyDrive/toxicCommentsDataSet/toxicCommentCNNModel.h5')
